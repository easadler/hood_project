# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ast
import re

from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
from sklearn.metrics import silhouette_samples, silhouette_score
from pymongo import MongoClient
import re

from scipy.spatial.distance import pdist, squareform
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram
# %matplotlib inline

# %%
city = 'Seattle'
state = 'WA'
client = MongoClient('localhost', 27017)
db = client['neighborhood_recommender']
collection = db['crime' + '_' + city + '_' + state]
cursor = collection.find()
data = [crime for crime in cursor]
df = pd.DataFrame(data)

# %%
df = df.ix[~df['hood'].isnull(), :]

# %%
counts = df.groupby(['hood','summarized_offense_description'])['offense_type'].count()
df = pd.DataFrame(counts).reset_index()

# %%
df = df.pivot(index = 'hood', values = 'offense_type', columns = 'summarized_offense_description')
names = df.index

# %%
mask = (df.dtypes == np.float64) | (df.dtypes == np.int)
df_sub = df.ix[:, mask]
df_sub = df_sub.fillna(0)
#df_sub = df_sub.dropna(axis = 1, thresh = 50)
a = df_sub.apply(lambda s : s.value_counts().get(0,0), axis=0)
a = a[a < 40].index
df_sub = df_sub[a]

# %%
pca = PCA(copy=True, n_components=3, whiten=False)
imp = preprocessing.Imputer(axis=0)
X = imp.fit_transform(df_sub)
X_centered = preprocessing.scale(X)
X_pca = pca.fit_transform(X_centered)
print(pca.explained_variance_ratio_)
# Out:
# [ 0.71153626  0.09754033  0.03830905]

# %%
df_c = pd.DataFrame(pca.components_.T, index = df_sub.columns, columns = [1,2,3])

# %%
df_c.sort(3,ascending = False)
# Out:
#                                        1         2         3
# summarized_offense_description
# FRAUD                           0.284616 -0.102832  0.576533
# BIKE THEFT                      0.288969 -0.015039  0.552715
# CAR PROWL                       0.302638  0.099483  0.225901
# STOLEN PROPERTY                 0.299175  0.163223 -0.009536
# OTHER PROPERTY                  0.312861  0.080684 -0.034374
# ASSAULT                         0.296929  0.292653 -0.082649
# PROPERTY DAMAGE                 0.299900 -0.201566 -0.085224
# VEHICLE THEFT                   0.233854 -0.579611 -0.183650
# THREATS                         0.310148  0.047892 -0.216589
# BURGLARY                        0.242591 -0.545114 -0.230280
# DISTURBANCE                     0.305474  0.148068 -0.244525
# WARRANT ARREST                  0.274521  0.403188 -0.319778

# %%
for i in [6]:
    clusterer = KMeans(n_clusters=i)
    cluster_labels = clusterer.fit_predict(X_pca)
    silhouette_avg = silhouette_score(X_pca, cluster_labels)
    print("For n_clusters =", i,
          "The average silhouette_score is :", silhouette_avg)
# Out:
# ('For n_clusters =', 6, 'The average silhouette_score is :', 0.4462577840729175)

# %%
plot_embedding(X_pca, cluster_labels, names)

# %%
link = linkage(df_sub.T,method='complete', metric = 'cosine')

# 5. Using scipy's dendrogram function plot the linkages as
# a hierachical tree.
plt.figure(figsize=(20,20))
dendro = dendrogram(link, color_threshold=0.1, leaf_rotation = 90, leaf_font_size=8, labels = df_sub.columns )
plt.subplots_adjust(top=.99, bottom=0.5, left=0.05, right=0.99)
plt.show()

# %%
def plot_embedding(X, y, name_list, title=None):
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    X = (X - x_min) / (x_max - x_min)
    plt.figure(figsize=(20, 20), dpi=250)
    ax = plt.subplot(111, projection='3d')
    #ax.axis('off')
    #ax.patch.set_visible(False)
    for i in range(X.shape[0]):
        ax.text(X[i, 0], X[i, 1],X[i,2], str(name_list[i]), color=plt.cm.Set1(y[i] / 10.), fontsize = 10)


#     ax.set_xlim3d(-1, 1.1)
#     ax.set_ylim3d(-1, 1.1)
#     ax.set_zlim3d(-1, 1.1)
    if title is not None:
        plt.title(title, fontsize=16)

# %%
# Out:
# summarized_offense_description  ANIMAL COMPLAINT  ASSAULT  BIAS INCIDENT  \
# hood
# Admiral                                       11      105            NaN
# Alki                                          14       50            NaN
# Arbor Heights                                  7       26            NaN
# Atlantic                                      14      234            NaN
# Ballard                                       16      434              1
# Beacon Hill                                   61      460              7
# Belltown                                      10      848              4
# Bitter Lake                                    8      145            NaN
# Blue Ridge                                   NaN        5            NaN
# Brighton                                      11      211              4
# Broadmoor                                    NaN       14            NaN
# Broadview                                      2       66            NaN
# Bryant                                         3       11            NaN
# Capitol Hill                                  46     1428             15
# Cedar Park                                     3      120              1
# Central District                              21      420              8
# Columbia City                                 12      168              2
# Crown Hill                                     1       51            NaN
# Denny-Blaine                                   1        3              2
# Downtown                                      63     3321              4
# Eastlake                                       2       87            NaN
# Fauntleroy                                     1       29            NaN
# First Hill                                    13     1027             10
# Fremont                                       19      225            NaN
# Georgetown                                    10      141            NaN
# Green Lake                                    12      113            NaN
# Greenwood                                     12      357            NaN
# Haller Lake                                   18      360            NaN
# Hawthorne Hills                              NaN      NaN            NaN
# High Point                                    18      180            NaN
# ...                                          ...      ...            ...
# North College Park                            26       91            NaN
# North Delridge                                 9       61              1
# Northgate                                      2      111            NaN
# Olympic Hills                                  6      158            NaN
# Olympic Manor                                  2        6            NaN
# Phinney Ridge                                  7       77              3
# Pinehurst                                     10       61            NaN
# Pioneer Square                                 9      652            NaN
# Portage Bay                                    2       13            NaN
# Queen Anne                                    17      131            NaN
# Rainier Beach                                 21      410             12
# Ravenna                                        9       64            NaN
# Riverview                                      5       30            NaN
# Roosevelt                                      5       54            NaN
# Roxhill                                        8       75            NaN
# Sand Point                                     5       19            NaN
# Seward Park                                    3       36            NaN
# South Delridge                                 9      152            NaN
# South Lake Union                             NaN      276            NaN
# South Park                                    16      161            NaN
# Sunset Hill                                    1       45            NaN
# University District                           15      770              2
# Victory Heights                                5       56            NaN
# View Ridge                                     2        6            NaN
# Wallingford                                    9      130            NaN
# Wedgwood                                     NaN       46            NaN
# West Seattle                                   8      267            NaN
# Westlake                                     NaN       72            NaN
# Whittier Heights                             NaN       17            NaN
# Windermere                                   NaN        4            NaN
#
# summarized_offense_description  BIKE THEFT  BURGLARY  \
# hood
# Admiral                                 59       333
# Alki                                    34        84
# Arbor Heights                            8       268
# Atlantic                                24       258
# Ballard                                280       688
# Beacon Hill                             79      1733
# Belltown                               166       408
# Bitter Lake                             48       297
# Blue Ridge                               2        63
# Brighton                                24       466
# Broadmoor                              NaN        31
# Broadview                               31       420
# Bryant                                  28       221
# Capitol Hill                           532      1475
# Cedar Park                              35       285
# Central District                       121       731
# Columbia City                           47       646
# Crown Hill                              19       113
# Denny-Blaine                             1        31
# Downtown                               631      1019
# Eastlake                                94       345
# Fauntleroy                               9       140
# First Hill                             248       535
# Fremont                                253       791
# Georgetown                              37       341
# Green Lake                             115       418
# Greenwood                              156       826
# Haller Lake                             75       652
# Hawthorne Hills                          2        51
# High Point                              13       202
# ...                                    ...       ...
# North College Park                      80       267
# North Delridge                          16       231
# Northgate                               62       212
# Olympic Hills                           40       388
# Olympic Manor                            9        73
# Phinney Ridge                           61       332
# Pinehurst                               16       225
# Pioneer Square                          59       224
# Portage Bay                             16       121
# Queen Anne                             158       983
# Rainier Beach                           24      1006
# Ravenna                                 46       463
# Riverview                                2       131
# Roosevelt                               47       157
# Roxhill                                 35       239
# Sand Point                               9        35
# Seward Park                             25       496
# South Delridge                          26       390
# South Lake Union                       173       297
# South Park                              27       344
# Sunset Hill                             45       245
# University District                    426      1287
# Victory Heights                         17       313
# View Ridge                               7       173
# Wallingford                            210       683
# Wedgwood                                29       546
# West Seattle                            95       824
# Westlake                                64       249
# Whittier Heights                        27       179
# Windermere                              40        93
#
# summarized_offense_description  BURGLARY-SECURE PARKING-RES  CAR PROWL  \
# hood
# Admiral                                                  19        400
# Alki                                                     42        142
# Arbor Heights                                           NaN        235
# Atlantic                                                  9        542
# Ballard                                                 153       1271
# Beacon Hill                                              10       1573
# Belltown                                                217       2076
# Bitter Lake                                              79        403
# Blue Ridge                                              NaN         62
# Brighton                                                 10        281
# Broadmoor                                               NaN        188
# Broadview                                                45        576
# Bryant                                                    2        144
# Capitol Hill                                            703       3310
# Cedar Park                                               31        168
# Central District                                        122       1437
# Columbia City                                             7        687
# Crown Hill                                                5        105
# Denny-Blaine                                              2         75
# Downtown                                                139       6400
# Eastlake                                                133        718
# Fauntleroy                                              NaN        443
# First Hill                                              270       2660
# Fremont                                                 180       1044
# Georgetown                                              NaN        336
# Green Lake                                               62       1236
# Greenwood                                               115       1039
# Haller Lake                                              12       1042
# Hawthorne Hills                                         NaN         55
# High Point                                                4        182
# ...                                                     ...        ...
# North College Park                                       29        452
# North Delridge                                           47        241
# Northgate                                                19        680
# Olympic Hills                                            63        221
# Olympic Manor                                           NaN         57
# Phinney Ridge                                            38        625
# Pinehurst                                                10        288
# Pioneer Square                                           10        798
# Portage Bay                                              18        220
# Queen Anne                                              176       2024
# Rainier Beach                                             6        923
# Ravenna                                                  18        460
# Riverview                                               NaN         96
# Roosevelt                                                32        236
# Roxhill                                                   7        377
# Sand Point                                              NaN         41
# Seward Park                                               1        751
# South Delridge                                            3        368
# South Lake Union                                         99        719
# South Park                                              NaN        196
# Sunset Hill                                              12        428
# University District                                     346       2006
# Victory Heights                                          10        180
# View Ridge                                                3        218
# Wallingford                                              98       1123
# Wedgwood                                                 27        360
# West Seattle                                             93        971
# Westlake                                                132        927
# Whittier Heights                                        NaN        233
# Windermere                                                2         74
#
# summarized_offense_description  COUNTERFEIT  DISORDERLY CONDUCT  DISPUTE  \
# hood
# Admiral                                   2                 NaN       21
# Alki                                    NaN                 NaN       11
# Arbor Heights                           NaN                 NaN        7
# Atlantic                                 11                   2       18
# Ballard                                  24                   1       33
# Beacon Hill                              18                   1       83
# Belltown                                  3                 NaN       33
# Bitter Lake                              13                 NaN       15
# Blue Ridge                              NaN                 NaN        2
# Brighton                                  8                 NaN       36
# Broadmoor                               NaN                 NaN        2
# Broadview                                 2                 NaN       26
# Bryant                                    3                 NaN        4
# Capitol Hill                             79                   9       48
# Cedar Park                                6                 NaN       11
# Central District                          8                   1       56
# Columbia City                             9                 NaN       34
# Crown Hill                               39                 NaN       10
# Denny-Blaine                            NaN                 NaN        4
# Downtown                                107                  18       89
# Eastlake                                  4                 NaN       10
# Fauntleroy                              NaN                 NaN        9
# First Hill                               26                   1       26
# Fremont                                   5                   3       26
# Georgetown                               20                 NaN       28
# Green Lake                                5                 NaN       27
# Greenwood                                65                 NaN       56
# Haller Lake                              87                 NaN       50
# Hawthorne Hills                         NaN                 NaN      NaN
# High Point                                3                 NaN       37
# ...                                     ...                 ...      ...
# North College Park                        4                 NaN       22
# North Delridge                            2                 NaN       10
# Northgate                                36                 NaN       10
# Olympic Hills                            17                   1       15
# Olympic Manor                           NaN                 NaN        4
# Phinney Ridge                             2                 NaN       14
# Pinehurst                                 3                 NaN        5
# Pioneer Square                           33                   8       15
# Portage Bay                             NaN                 NaN        1
# Queen Anne                                9                   2       35
# Rainier Beach                            14                 NaN       71
# Ravenna                                   4                 NaN        7
# Riverview                                 2                 NaN       16
# Roosevelt                                 9                 NaN        6
# Roxhill                                   4                 NaN       15
# Sand Point                              NaN                 NaN        1
# Seward Park                             NaN                 NaN       16
# South Delridge                           13                   2       23
# South Lake Union                          6                 NaN       21
# South Park                              NaN                 NaN       22
# Sunset Hill                             NaN                 NaN        5
# University District                      12                   1       51
# Victory Heights                          35                 NaN        9
# View Ridge                                2                 NaN        7
# Wallingford                              44                 NaN       15
# Wedgwood                                NaN                 NaN        7
# West Seattle                             14                   2       36
# Westlake                                  4                 NaN        7
# Whittier Heights                        NaN                 NaN        3
# Windermere                              NaN                 NaN      NaN
#
# summarized_offense_description            ...             STOLEN PROPERTY  \
# hood                                      ...
# Admiral                                   ...                          90
# Alki                                      ...                         121
# Arbor Heights                             ...                          42
# Atlantic                                  ...                          93
# Ballard                                   ...                         227
# Beacon Hill                               ...                         348
# Belltown                                  ...                         249
# Bitter Lake                               ...                         104
# Blue Ridge                                ...                           3
# Brighton                                  ...                          53
# Broadmoor                                 ...                          12
# Broadview                                 ...                          61
# Bryant                                    ...                          16
# Capitol Hill                              ...                        1207
# Cedar Park                                ...                          43
# Central District                          ...                         251
# Columbia City                             ...                         133
# Crown Hill                                ...                          37
# Denny-Blaine                              ...                          11
# Downtown                                  ...                        1652
# Eastlake                                  ...                         100
# Fauntleroy                                ...                          64
# First Hill                                ...                         316
# Fremont                                   ...                         136
# Georgetown                                ...                          94
# Green Lake                                ...                         167
# Greenwood                                 ...                         283
# Haller Lake                               ...                         192
# Hawthorne Hills                           ...                           4
# High Point                                ...                         144
# ...                                       ...                         ...
# North College Park                        ...                         342
# North Delridge                            ...                          53
# Northgate                                 ...                          98
# Olympic Hills                             ...                          65
# Olympic Manor                             ...                          19
# Phinney Ridge                             ...                          68
# Pinehurst                                 ...                          30
# Pioneer Square                            ...                         186
# Portage Bay                               ...                          18
# Queen Anne                                ...                         183
# Rainier Beach                             ...                         126
# Ravenna                                   ...                          80
# Riverview                                 ...                          34
# Roosevelt                                 ...                          68
# Roxhill                                   ...                          85
# Sand Point                                ...                          13
# Seward Park                               ...                          59
# South Delridge                            ...                         117
# South Lake Union                          ...                         120
# South Park                                ...                          45
# Sunset Hill                               ...                          37
# University District                       ...                         381
# Victory Heights                           ...                          32
# View Ridge                                ...                          17
# Wallingford                               ...                         169
# Wedgwood                                  ...                          61
# West Seattle                              ...                         232
# Westlake                                  ...                          89
# Whittier Heights                          ...                          33
# Windermere                                ...                           4
#
# summarized_offense_description  THEFT OF SERVICES  THREATS  TRAFFIC  TRESPASS  \
# hood
# Admiral                                         4       95       16        24
# Alki                                            9       34        6         7
# Arbor Heights                                   2       30        2         7
# Atlantic                                       10      211       44        94
# Ballard                                        27      263       45       163
# Beacon Hill                                    16      402      108        85
# Belltown                                       41      326       67       100
# Bitter Lake                                     5      142       20        27
# Blue Ridge                                    NaN       12        2         2
# Brighton                                      NaN      128       41        15
# Broadmoor                                     NaN        6        2       NaN
# Broadview                                       4       91        9        34
# Bryant                                          2       56      NaN         6
# Capitol Hill                                   92      662      111       454
# Cedar Park                                      5      119        7        24
# Central District                               20      314       70       136
# Columbia City                                  12      186       44        28
# Crown Hill                                      2       66        6        19
# Denny-Blaine                                  NaN        4        2         5
# Downtown                                      244     1079      210       719
# Eastlake                                        4       73        7        15
# Fauntleroy                                      4       39       10         3
# First Hill                                     48      386       66       265
# Fremont                                         9      143       41        64
# Georgetown                                      7      101       40        26
# Green Lake                                      9       60        9        51
# Greenwood                                      45      284       34       150
# Haller Lake                                    26      204       48       130
# Hawthorne Hills                               NaN        4        1       NaN
# High Point                                      2      125       15        12
# ...                                           ...      ...      ...       ...
# North College Park                              7       93       18        52
# North Delridge                                 11       77       11        23
# Northgate                                      17      116        9        50
# Olympic Hills                                   7      157       20        37
# Olympic Manor                                 NaN       12      NaN         4
# Phinney Ridge                                   1       93        9        13
# Pinehurst                                       5       57        9        24
# Pioneer Square                                 37      186       22       116
# Portage Bay                                   NaN       12        3         2
# Queen Anne                                      8      192       30        53
# Rainier Beach                                  15      283       72        84
# Ravenna                                         2       93        6        21
# Riverview                                       3       44        4         9
# Roosevelt                                       1       52        5        33
# Roxhill                                         9       76        8        35
# Sand Point                                    NaN       19        2         2
# Seward Park                                     1       60       12        21
# South Delridge                                  1       95       17        80
# South Lake Union                               30      118       27        83
# South Park                                      8      131       16        40
# Sunset Hill                                     5       36       10        13
# University District                            48      378       42       245
# Victory Heights                               NaN       69        1        14
# View Ridge                                      1       15        6       NaN
# Wallingford                                    13      124       37        75
# Wedgwood                                       11       96       13        11
# West Seattle                                   26      202       38        82
# Westlake                                        5       35       19        15
# Whittier Heights                                5       37        6         6
# Windermere                                      1        2      NaN       NaN
#
# summarized_offense_description  VEHICLE THEFT  VIOLATION OF COURT ORDER  \
# hood
# Admiral                                   146                         4
# Alki                                      110                         1
# Arbor Heights                              76                         1
# Atlantic                                  153                        19
# Ballard                                   793                        16
# Beacon Hill                              1365                        25
# Belltown                                  289                        31
# Bitter Lake                               289                        11
# Blue Ridge                                 20                         4
# Brighton                                  412                        10
# Broadmoor                                  13                       NaN
# Broadview                                 237                        22
# Bryant                                     89                         2
# Capitol Hill                             1389                        37
# Cedar Park                                161                         4
# Central District                          451                        26
# Columbia City                             429                        16
# Crown Hill                                 84                         4
# Denny-Blaine                                7                       NaN
# Downtown                                  649                       111
# Eastlake                                  347                         6
# Fauntleroy                                127                         6
# First Hill                                469                        31
# Fremont                                   663                        40
# Georgetown                                300                        10
# Green Lake                                471                        11
# Greenwood                                 835                        72
# Haller Lake                               502                         9
# Hawthorne Hills                            15                       NaN
# High Point                                191                        11
# ...                                       ...                       ...
# North College Park                        299                         6
# North Delridge                            123                         1
# Northgate                                 483                         4
# Olympic Hills                             235                        24
# Olympic Manor                              22                       NaN
# Phinney Ridge                             349                        14
# Pinehurst                                 228                       NaN
# Pioneer Square                             80                        20
# Portage Bay                                83                       NaN
# Queen Anne                                630                        34
# Rainier Beach                             889                        14
# Ravenna                                   294                         5
# Riverview                                 140                         5
# Roosevelt                                 248                       NaN
# Roxhill                                   154                         2
# Sand Point                                 13                       NaN
# Seward Park                               141                         3
# South Delridge                            419                         6
# South Lake Union                          126                        18
# South Park                                309                        11
# Sunset Hill                               132                         7
# University District                      1005                        18
# Victory Heights                           142                         6
# View Ridge                                 79                         2
# Wallingford                               661                         5
# Wedgwood                                  232                         8
# West Seattle                              577                        35
# Westlake                                  213                       NaN
# Whittier Heights                          123                        16
# Windermere                                 31                         1
#
# summarized_offense_description  WARRANT ARREST  WEAPON  \
# hood
# Admiral                                     47       8
# Alki                                        15       7
# Arbor Heights                                9       2
# Atlantic                                   158      14
# Ballard                                    171      11
# Beacon Hill                                285      50
# Belltown                                   360      49
# Bitter Lake                                 87      10
# Blue Ridge                                   4     NaN
# Brighton                                   143      30
# Broadmoor                                    2     NaN
# Broadview                                   30      14
# Bryant                                      11       2
# Capitol Hill                               875     140
# Cedar Park                                  90       9
# Central District                           267      42
# Columbia City                               76      30
# Crown Hill                                  25       6
# Denny-Blaine                                 5       2
# Downtown                                  3098     207
# Eastlake                                    31     NaN
# Fauntleroy                                  23       1
# First Hill                                 481      65
# Fremont                                     77       8
# Georgetown                                 149      18
# Green Lake                                  26       7
# Greenwood                                  294      29
# Haller Lake                                321      48
# Hawthorne Hills                            NaN     NaN
# High Point                                  83      21
# ...                                        ...     ...
# North College Park                          94      10
# North Delridge                              35       9
# Northgate                                   54       5
# Olympic Hills                              110      22
# Olympic Manor                                5     NaN
# Phinney Ridge                               16       4
# Pinehurst                                   19       5
# Pioneer Square                             346      52
# Portage Bay                                  9       2
# Queen Anne                                  58      12
# Rainier Beach                              288      88
# Ravenna                                     32       3
# Riverview                                   19       4
# Roosevelt                                   26       5
# Roxhill                                     64       8
# Sand Point                                   6       3
# Seward Park                                 19       6
# South Delridge                             118      24
# South Lake Union                           110       7
# South Park                                 110      27
# Sunset Hill                                 19       3
# University District                        279      60
# Victory Heights                             44       5
# View Ridge                                   2     NaN
# Wallingford                                 44       8
# Wedgwood                                    29       2
# West Seattle                                95      20
# Westlake                                    21       3
# Whittier Heights                            10       2
# Windermere                                 NaN     NaN
#
# summarized_offense_description  [INC - CASE DC USE ONLY]
# hood
# Admiral                                              NaN
# Alki                                                 NaN
# Arbor Heights                                        NaN
# Atlantic                                             NaN
# Ballard                                              NaN
# Beacon Hill                                          NaN
# Belltown                                             NaN
# Bitter Lake                                          NaN
# Blue Ridge                                           NaN
# Brighton                                             NaN
# Broadmoor                                            NaN
# Broadview                                              3
# Bryant                                               NaN
# Capitol Hill                                           3
# Cedar Park                                             2
# Central District                                     NaN
# Columbia City                                        NaN
# Crown Hill                                           NaN
# Denny-Blaine                                         NaN
# Downtown                                              18
# Eastlake                                             NaN
# Fauntleroy                                           NaN
# First Hill                                             2
# Fremont                                              NaN
# Georgetown                                           NaN
# Green Lake                                           NaN
# Greenwood                                            NaN
# Haller Lake                                            3
# Hawthorne Hills                                      NaN
# High Point                                           NaN
# ...                                                  ...
# North College Park                                   NaN
# North Delridge                                       NaN
# Northgate                                            NaN
# Olympic Hills                                        NaN
# Olympic Manor                                        NaN
# Phinney Ridge                                        NaN
# Pinehurst                                            NaN
# Pioneer Square                                         5
# Portage Bay                                          NaN
# Queen Anne                                           NaN
# Rainier Beach                                        NaN
# Ravenna                                              NaN
# Riverview                                            NaN
# Roosevelt                                            NaN
# Roxhill                                              NaN
# Sand Point                                           NaN
# Seward Park                                          NaN
# South Delridge                                       NaN
# South Lake Union                                       2
# South Park                                           NaN
# Sunset Hill                                          NaN
# University District                                  NaN
# Victory Heights                                      NaN
# View Ridge                                           NaN
# Wallingford                                          NaN
# Wedgwood                                             NaN
# West Seattle                                           1
# Westlake                                             NaN
# Whittier Heights                                     NaN
# Windermere                                           NaN
#
# [78 rows x 56 columns]

# %%
# Out:
# array([[  1.45456707e+00,  -5.01493119e-02,   4.76009790e-01],
#        [  2.33882883e+00,  -8.89620241e-01,  -2.87750461e-01],
#        [  2.89557440e+00,  -4.67744298e-01,  -3.09303715e-02],
#        [ -1.86062119e-01,  -2.29229288e-01,   1.12801308e+00],
#        [ -3.93455823e+00,   1.99486607e+00,  -9.15082752e-01],
#        [ -7.45691276e+00,   7.49922668e+00,   4.48236204e+00],
#        [ -4.26780767e+00,  -1.15869505e+00,  -7.45904209e-01],
#        [  8.45893869e-01,   5.36028263e-01,   2.46619511e-01],
#        [  3.50908934e+00,  -1.22054479e+00,  -3.47913526e-01],
#        [  6.20481278e-02,   6.12031573e-01,   7.77142172e-01],
#        [  3.64507664e+00,  -1.52902082e+00,  -2.91380104e-01],
#        [  1.29728641e+00,   6.32039416e-01,  -2.10391055e-01],
#        [  3.04403981e+00,  -1.10113300e+00,  -2.31325822e-01],
#        [ -1.82330253e+01,   4.42067965e+00,  -5.03407142e+00],
#        [  1.83626355e+00,  -1.89336334e-01,   1.16442261e-01],
#        [ -3.97098705e+00,   2.03202723e+00,   3.61650430e-01],
#        [ -4.12467096e-01,   8.54457086e-01,   5.86603388e-01],
#        [  2.32846393e+00,  -7.32207605e-01,   1.23621951e-01],
#        [  3.58201598e+00,  -1.53064518e+00,  -1.09648116e-01],
#        [ -3.24310987e+01,  -9.11572110e+00,   2.65845633e+00],
#        [  1.51962849e+00,   2.15890497e-02,  -8.09331235e-01],
#        [  2.72420006e+00,  -8.83024171e-01,  -2.92166392e-01],
#        [ -8.80578754e+00,  -3.60519183e-01,  -3.67254762e+00],
#        [ -1.39217618e+00,   1.72542298e+00,  -6.41693699e-01],
#        [  2.95138060e-01,   8.44740655e-01,   1.11510943e+00],
#        [  5.91402630e-01,   4.68054729e-01,  -3.09295081e-01],
#        [ -4.71259890e+00,   2.36666004e+00,   4.24942493e-02],
#        [ -3.44360907e+00,   1.69303030e+00,   1.67382743e+00],
#        [  3.68593654e+00,  -1.50945801e+00,  -2.13971952e-01],
#        [  1.20318543e+00,  -2.11435284e-01,   8.83840264e-01],
#        [  1.06470215e+00,   1.46914770e+00,   7.57166489e-01],
#        [ -3.32770703e+00,   6.06034915e-01,   1.80056043e+00],
#        [  2.45204766e+00,  -7.75608890e-01,  -2.85067750e-01],
#        [ -3.65671071e+00,  -1.21745873e+00,   4.63733735e-01],
#        [  3.28999444e+00,  -1.14787653e+00,  -3.29498940e-01],
#        [  2.43925904e+00,  -3.93478385e-01,   5.08769487e-01],
#        [ -1.58255515e+00,   2.13641424e-01,  -1.44930260e+00],
#        [  1.73282655e+00,  -4.11214901e-01,  -6.47224073e-01],
#        [  3.13106993e+00,  -1.01453669e+00,  -2.70263865e-01],
#        [  3.57681251e+00,  -1.40855617e+00,  -2.43609447e-01],
#        [  2.71479649e+00,  -8.33730203e-01,   1.00535752e-01],
#        [  3.95722845e-01,   1.41390400e+00,  -3.85403377e-01],
#        [  1.23746753e+00,   1.29304383e+00,   6.06242253e-01],
#        [  2.70153099e+00,  -1.88690757e-01,  -3.84559503e-03],
#        [  2.50045143e+00,  -2.39717692e-01,   1.58047298e-01],
#        [  3.30862915e+00,  -1.48821902e+00,  -3.28899450e-01],
#        [ -3.54920375e-01,   1.09340741e+00,   1.40876373e+00],
#        [  3.52171330e+00,  -1.24023052e+00,  -1.38950863e-01],
#        [  2.67432706e-01,   1.44366074e+00,   4.92692811e-01],
#        [  2.15722623e+00,  -3.70178038e-01,  -4.16487880e-02],
#        [  1.62022025e-01,  -1.41216028e+00,  -7.30938882e-02],
#        [  3.32267797e-01,   8.31579637e-01,  -3.39706283e-02],
#        [  3.44894393e+00,  -1.30239540e+00,  -2.69727584e-01],
#        [  1.55451961e+00,   1.26350281e-02,  -4.19738385e-01],
#        [  1.97467461e+00,   2.33956677e-01,   6.58816537e-01],
#        [ -2.40203134e+00,  -3.26362724e+00,   2.27233432e-01],
#        [  3.38390007e+00,  -1.15175230e+00,  -2.70136192e-01],
#        [ -1.74144894e+00,   2.59081555e+00,  -7.00928004e-01],
#        [ -3.94034488e+00,   3.40408333e+00,   3.04182959e+00],
#        [  1.80357151e+00,   2.17817304e-02,  -1.15526711e-01],
#        [  2.37208793e+00,   1.66108593e-01,   4.69956378e-01],
#        [  2.38453177e+00,  -6.89430082e-01,  -3.78235923e-01],
#        [  1.55402752e+00,  -8.54346123e-01,  -3.71383760e-02],
#        [  3.52897780e+00,  -1.51673531e+00,  -2.63033086e-02],
#        [  2.46965504e+00,  -3.43212479e-01,  -1.89842222e-02],
#        [  5.48429120e-01,   2.99834841e-01,   6.57411202e-01],
#        [  1.10876684e-01,  -1.34999736e+00,  -7.81734282e-01],
#        [  1.03370982e+00,   1.96808484e-01,   1.32529999e+00],
#        [  2.32914461e+00,  -1.08111066e+00,  -5.17475001e-01],
#        [ -8.68451885e+00,   3.54091627e+00,  -2.77728023e+00],
#        [  2.29280371e+00,   1.77211053e-02,   2.31590126e-01],
#        [  3.17045288e+00,  -1.01306260e+00,  -2.13801896e-01],
#        [ -9.54462549e-01,   1.45278859e+00,  -9.01766502e-01],
#        [  1.88593602e+00,   4.73905246e-01,  -1.04573923e-01],
#        [ -2.37713050e+00,   2.29674002e+00,  -1.31856398e-01],
#        [  1.99589178e+00,  -4.95204788e-01,  -1.09049392e+00],
#        [  3.01889932e+00,  -1.04819757e+00,  -2.33509594e-01],
#        [  3.56327528e+00,  -1.34415648e+00,  -2.17448045e-01]])

# %%
# Out:
# array([ 1.99589178, -0.49520479, -1.09049392])
